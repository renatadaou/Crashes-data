# %% [markdown]
# ## 1) Exploring the crashes

# %% [markdown]
# Just by looking at the spreadsheet we can see that there are 136 idependent crahes.

# %% [markdown]
# I want to look at juist the Town Name, Date Of Crash, Number Of Motor Vehicles, Light Condition Text Format

# %%
import pandas as pd

# %%
# Load the newly provided CSV file
file_path = 'export_182420_0.csv'
data = pd.read_csv(file_path)

# Display the first few rows to identify the correct columns
data.head()
# Out:
#    CrashId  Fatal Case Status Fatal Case Status Text Format  CrashId.1  \
# 0  1120523                  1                      Complete    1120523
# 1  1120633                  1                      Complete    1120633
# 2  1122370                  1                      Complete    1122370
# 3  1124976                  1                      Complete    1124976
# 4  1126594                  1                      Complete    1126594
#
#    CrashId.2   Latitude  Longitude  DOT Case Number   Town Name  Town Number  \
# 0    1120523  41.656084 -72.914214           924017     Bristol           17
# 1    1120633  41.228910 -73.031433           924004     Milford           84
# 2    1122370  41.381282 -71.898517           924008  Stonington          137
# 3    1124976  41.319335 -73.095853           924016     Shelton          126
# 4    1126594  41.389921 -73.209324           924012     Newtown           97
#
#    ...  Police Case Status Police Case Status Text Format  \
# 0  ...                   C                         Closed
# 1  ...                   C                         Closed
# 2  ...                   O                           Open
# 3  ...                   O                           Open
# 4  ...                   O                           Open
#
#   Crash Report Submission Date  Related Case Identifiers  \
# 0                      59:24.0                       NaN
# 1                      00:04.0                2024000046
# 2                      55:44.0                2400014528
# 3                      51:51.0                       NaN
# 4                      21:35.0                       NaN
#
#    No. of Through Lanes (Log Dir.) Average Daily Traffic  \
# 0                              4.0               19200.0
# 1                              2.0               16900.0
# 2                              4.0               41300.0
# 3                              2.0               10800.0
# 4                              2.0               10800.0
#
#    Functional Classification  Functional Classification Text Format  \
# 0                        3.0  PRINCIPAL ARTERIAL - OTHER - NEW HPMS
# 1                        4.0              MINOR ARTERIAL - NEW HPMS
# 2                        1.0                  INTERSTATE - NEW HPMS
# 3                        4.0              MINOR ARTERIAL - NEW HPMS
# 4                        3.0  PRINCIPAL ARTERIAL - OTHER - NEW HPMS
#
#   Rural or Urban Rural or Urban Text Format
# 0            2.0                      Urban
# 1            2.0                      Urban
# 2            2.0                      Urban
# 3            2.0                      Urban
# 4            2.0                      Urban
#
# [5 rows x 103 columns]

# %%
# Extract the relevant columns
filtered_data = data[['Town Name','Latitude','Longitude', 'Date Of Crash', 'Number Of Motor Vehicles', 'Light Condition Text Format']]

# Save the filtered data to a new CSV file
output_file_path = 'filtered_crash_data_final.csv'
filtered_data.to_csv(output_file_path, index=False)

output_file_path
# Out:
# 'filtered_crash_data_final.csv'

# %%
#show the data
filtered_data = pd.read_csv('filtered_crash_data_final.csv')
filtered_data
# Out:
#          Town Name   Latitude  Longitude Date Of Crash  \
# 0          Bristol  41.656084 -72.914214        1/5/24
# 1          Milford  41.228910 -73.031433        1/2/24
# 2       Stonington  41.381282 -71.898517       1/11/24
# 3          Shelton  41.319335 -73.095853        1/6/24
# 4          Newtown  41.389921 -73.209324       1/20/24
# ..             ...        ...        ...           ...
# 132       Griswold  41.606730 -71.912143        6/1/24
# 133      Voluntown  41.589718 -71.832609       7/25/24
# 134        Milford  41.232069 -73.045685       8/13/24
# 135     Ridgefield  41.269356 -73.442064       8/25/24
# 136  West Hartford  41.735254 -72.744102       8/17/24
#
#      Number Of Motor Vehicles Light Condition Text Format
# 0                           2                    Daylight
# 1                           1                    Daylight
# 2                           3                    Daylight
# 3                           3                Dark-Lighted
# 4                           2                    Daylight
# ..                        ...                         ...
# 132                         2                    Daylight
# 133                         1                     Unknown
# 134                         2                    Daylight
# 135                         2            Dark-Not Lighted
# 136                         1                    Daylight
#
# [137 rows x 6 columns]
