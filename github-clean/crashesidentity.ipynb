# %% [markdown]
# ## 1) CLEANING THE DATA
# I WILL FIRST START LOOKING AT ALL CRASH DATA THAT INVOLVES AT LEAST 1 FATALITY

# %% [markdown]
# This is only the demograpics of the people who were killed in car accidents so far in 2024.

# %% [markdown]
# CrashID shows all the crahes. There can be more than one person involved in a crah, but not necessarely all of them were killed. To analyse the demograophics of the people who were unfortunately killed, I will filter just by the unique values in the "Injury Status Text Format" column to understand its contents and filter by Fatal Injury (K).

# %%
import pandas as pd

# %%
# Load the file again, as a new file was uploaded, which might have replaced the previous one
file_path = 'export_182359_2.csv'
data = pd.read_csv(file_path, encoding='latin1')

# Filter the data for only rows where "Injury Status" is "Fatal Injury (K)"
fatal_injury_data = data[data['Injury Status Text Format'] == 'Fatal Injury (K)']

# Display the number of instances with "Fatal Injury (K)"
fatal_injury_count = fatal_injury_data.shape[0]
fatal_injury_count
# Out:
# 146

# %%
fatal_injury_k_data = data[data['Injury Status Text Format'] == 'Fatal Injury (K)']

# Display the filtered data
fatal_injury_k_data
# Out:
#      CrashId  VehicleId  PersonId   Age  Gender Gender Text Format State  \
# 2    1120523        1.0         3  69.0       1               Male    CT
# 4    1120633        1.0         1  41.0       1               Male    CT
# 7    1122370        1.0         1  78.0       2             Female    CT
# 9    1124976        NaN         2  64.0       2             Female    CT
# 12   1126594        1.0         1  75.0       1               Male    CT
# ..       ...        ...       ...   ...     ...                ...   ...
# 366  1193409        1.0         1  60.0       1               Male    CT
# 367  1193483        1.0         1  55.0       1               Male    CT
# 369  1193508        1.0         1  55.0       1               Male    CT
# 376  1193880        2.0         2  65.0       1               Male    CT
# 379  1194778        1.0         1  20.0       1               Male    CT
#
#     Postal Code  Person Type Person Type Text Format Injury Status  \
# 2          6787            2               Passenger             K
# 4          6460            1                  Driver             K
# 7          6254            1                  Driver             K
# 9          6484            3              Pedestrian             K
# 12         6804            1                  Driver             K
# ..          ...          ...                     ...           ...
# 366        6365            1                  Driver             K
# 367        6351            1                  Driver             K
# 369        6351            1                  Driver             K
# 376        6460            1                  Driver             K
# 379        6811            1                  Driver             K
#
#     Injury Status Text Format  Condition at Time of Crash  \
# 2            Fatal Injury (K)                         NaN
# 4            Fatal Injury (K)                         6.0
# 7            Fatal Injury (K)                         2.0
# 9            Fatal Injury (K)                        99.0
# 12           Fatal Injury (K)                        97.0
# ..                        ...                         ...
# 366          Fatal Injury (K)                         2.0
# 367          Fatal Injury (K)                         2.0
# 369          Fatal Injury (K)                         2.0
# 376          Fatal Injury (K)                        99.0
# 379          Fatal Injury (K)                        97.0
#
#                Condition at Time of Crash Text Format  \
# 2                                                 NaN
# 4    Under the Influence of Medications/Drugs/Alcohol
# 7                                 Physically Impaired
# 9                                             Unknown
# 12                                              Other
# ..                                                ...
# 366                               Physically Impaired
# 367                               Physically Impaired
# 369                               Physically Impaired
# 376                                           Unknown
# 379                                             Other
#
#      Condition at Time of Crash2  \
# 2                            NaN
# 4                            6.0
# 7                           88.0
# 9                           88.0
# 12                          88.0
# ..                           ...
# 366                         88.0
# 367                         88.0
# 369                         88.0
# 376                         99.0
# 379                         88.0
#
#               Condition at Time of Crash2 Text Format  \
# 2                                                 NaN
# 4    Under the Influence of Medications/Drugs/Alcohol
# 7                                      Not Applicable
# 9                                      Not Applicable
# 12                                     Not Applicable
# ..                                                ...
# 366                                    Not Applicable
# 367                                    Not Applicable
# 369                                    Not Applicable
# 376                                           Unknown
# 379                                    Not Applicable
#
#      Action Taken by Officer Action Taken by Officer Text Format  \
# 2                        NaN                                 NaN
# 4                        4.0                      Arrest/Summons
# 7                        0.0                          None taken
# 9                        0.0                          None taken
# 12                       0.0                          None taken
# ..                       ...                                 ...
# 366                      0.0                          None taken
# 367                      0.0                          None taken
# 369                      0.0                          None taken
# 376                      0.0                          None taken
# 379                      0.0                          None taken
#
#      Alcohol Test Status Alcohol Test Status Text Format  \
# 2                    1.0                  Test Not Given
# 4                    2.0                    Test Refused
# 7                    3.0                      Test Given
# 9                    1.0                  Test Not Given
# 12                   1.0                  Test Not Given
# ..                   ...                             ...
# 366                  1.0                  Test Not Given
# 367                  3.0                      Test Given
# 369                  3.0                      Test Given
# 376                  1.0                  Test Not Given
# 379                  1.0                  Test Not Given
#
#      Type Of Alcohol Test Type Of Alcohol Test Text Format  Drug Test Status  \
# 2                    88.0                   Not Applicable               1.0
# 4                     3.0                           Breath               2.0
# 7                     1.0                            Blood               3.0
# 9                    88.0                   Not Applicable               1.0
# 12                   88.0                   Not Applicable               1.0
# ..                    ...                              ...               ...
# 366                  88.0                   Not Applicable               1.0
# 367                  97.0                            Other               3.0
# 369                  97.0                            Other               3.0
# 376                  88.0                   Not Applicable               1.0
# 379                  88.0                   Not Applicable               1.0
#
#     Drug Test Status Text Format  Type Of Drig Test  \
# 2                 Test Not Given               88.0
# 4                   Test Refused                2.0
# 7                     Test Given                1.0
# 9                 Test Not Given               88.0
# 12                Test Not Given               88.0
# ..                           ...                ...
# 366               Test Not Given               88.0
# 367                   Test Given               97.0
# 369                   Test Given               97.0
# 376               Test Not Given               88.0
# 379               Test Not Given               88.0
#
#     Type Of Drig Test Text Format  Ejection Status  \
# 2                  Not Applicable              1.0
# 4                           Urine              1.0
# 7                           Blood              1.0
# 9                  Not Applicable              NaN
# 12                 Not Applicable              1.0
# ..                            ...              ...
# 366                Not Applicable              1.0
# 367                         Other              1.0
# 369                         Other              1.0
# 376                Not Applicable              1.0
# 379                Not Applicable              1.0
#
#     Ejection Status Text Format  Restraint System  \
# 2                   Not Ejected               1.0
# 4                   Not Ejected               1.0
# 7                   Not Ejected               1.0
# 9                           NaN               NaN
# 12                  Not Ejected               0.0
# ..                          ...               ...
# 366                 Not Ejected              99.0
# 367                 Not Ejected              88.0
# 369                 Not Ejected              88.0
# 376                 Not Ejected              88.0
# 379                 Not Ejected               0.0
#
#          Restraint System Text Format  Helmet Use  \
# 2          Shoulder and Lap Belt Used        88.0
# 4          Shoulder and Lap Belt Used        88.0
# 7          Shoulder and Lap Belt Used        88.0
# 9                                 NaN         NaN
# 12   None Used-Motor Vehicle Occupant        88.0
# ..                                ...         ...
# 366                           Unknown        88.0
# 367                    Not Applicable         1.0
# 369                    Not Applicable         2.0
# 376                    Not Applicable         1.0
# 379  None Used-Motor Vehicle Occupant        88.0
#
#               Helmet Use Text Format  Air Bag Status  \
# 2                     Not Applicable             2.0
# 4                     Not Applicable             2.0
# 7                     Not Applicable             6.0
# 9                                NaN             NaN
# 12                    Not Applicable            88.0
# ..                               ...             ...
# 366                   Not Applicable            88.0
# 367                        No Helmet            88.0
# 369  DOT-Compliant Motorcycle Helmet            88.0
# 376                        No Helmet            88.0
# 379                   Not Applicable             6.0
#
#     Air Bag Status Text Format  Speeding Related Speeding Related Text Format  \
# 2               Deployed-Front               NaN                          NaN
# 4               Deployed-Front               1.0                           No
# 7         Deployed-Combination               1.0                           No
# 9                          NaN               NaN                          NaN
# 12              Not applicable              99.0                      Unknown
# ..                         ...               ...                          ...
# 366             Not applicable              99.0                      Unknown
# 367             Not applicable              99.0                      Unknown
# 369             Not applicable              99.0                      Unknown
# 376             Not applicable               1.0                           No
# 379       Deployed-Combination               3.0         Exceeded Speed Limit
#
#      Driver Actions 1   Driver Actions 1 Text Format  Driver Actions 2  \
# 2                88.0                 Not Applicable              88.0
# 4                 2.0                Ran Off Roadway              88.0
# 7                 1.0         No Contributing Action              88.0
# 9                 NaN                            NaN               NaN
# 12               12.0           Followed Too Closely              16.0
# ..                ...                            ...               ...
# 366              99.0                        Unknown              88.0
# 367              99.0                        Unknown              88.0
# 369               2.0                Ran Off Roadway              88.0
# 376               1.0         No Contributing Action              88.0
# 379              13.0  Failed to Keep in Proper Lane              14.0
#
#                           Driver Actions 2 Text Format  Driver Actions 3  \
# 2                                       Not Applicable              88.0
# 4                                       Not Applicable              88.0
# 7                                       Not Applicable              88.0
# 9                                                  NaN               NaN
# 12   Swerved or Avoided Due to Wind, Slippery Surfa...              13.0
# ..                                                 ...               ...
# 366                                     Not Applicable              88.0
# 367                                     Not Applicable              88.0
# 369                                     Not Applicable              88.0
# 376                                     Not Applicable              88.0
# 379  Operated Motor Vehicle in Reckless or Aggressi...              88.0
#
#       Driver Actions 3 Text Format  Driver Actions 4  \
# 2                   Not Applicable              88.0
# 4                   Not Applicable              88.0
# 7                   Not Applicable              88.0
# 9                              NaN               NaN
# 12   Failed to Keep in Proper Lane              88.0
# ..                             ...               ...
# 366                 Not Applicable              88.0
# 367                 Not Applicable              88.0
# 369                 Not Applicable              88.0
# 376                 Not Applicable              88.0
# 379                 Not Applicable              88.0
#
#     Driver Actions 4 Text Format  Driver Distracted By  \
# 2                 Not Applicable                   NaN
# 4                 Not Applicable                   1.0
# 7                 Not Applicable                  99.0
# 9                            NaN                   NaN
# 12                Not Applicable                  99.0
# ..                           ...                   ...
# 366               Not Applicable                  99.0
# 367               Not Applicable                  99.0
# 369               Not Applicable                  99.0
# 376               Not Applicable                  99.0
# 379               Not Applicable                  99.0
#
#     Driver Distracted By Text Format  \
# 2                                NaN
# 4                     Not Distracted
# 7              Unknown if Distracted
# 9                                NaN
# 12             Unknown if Distracted
# ..                               ...
# 366            Unknown if Distracted
# 367            Unknown if Distracted
# 369            Unknown if Distracted
# 376            Unknown if Distracted
# 379            Unknown if Distracted
#
#     Roadway On Which Nonmotorist Was Traveling/Located  \
# 2                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 9                                          Howe Avenue
# 12                                                 NaN
# ..                                                 ...
# 366                                                NaN
# 367                                                NaN
# 369                                                NaN
# 376                                                NaN
# 379                                                NaN
#
#     Direction nonmotorist was traveling Direction Unknown  \
# 2                                   NaN               NaN
# 4                                   NaN               NaN
# 7                                   NaN               NaN
# 9                                     S             False
# 12                                  NaN               NaN
# ..                                  ...               ...
# 366                                 NaN               NaN
# 367                                 NaN               NaN
# 369                                 NaN               NaN
# 376                                 NaN               NaN
# 379                                 NaN               NaN
#
#      Striking Motor Vehicle ID  Bicycle ID Non-Motorist Not In Roadway  \
# 2                          NaN         NaN                         NaN
# 4                          NaN         NaN                         NaN
# 7                          NaN         NaN                         NaN
# 9                          1.0         NaN                       False
# 12                         NaN         NaN                         NaN
# ..                         ...         ...                         ...
# 366                        NaN         NaN                         NaN
# 367                        NaN         NaN                         NaN
# 369                        NaN         NaN                         NaN
# 376                        NaN         NaN                         NaN
# 379                        NaN         NaN                         NaN
#
#      Actions or Circumstances Prior to Crash  \
# 2                                        NaN
# 4                                        NaN
# 7                                        NaN
# 9                                        1.0
# 12                                       NaN
# ..                                       ...
# 366                                      NaN
# 367                                      NaN
# 369                                      NaN
# 376                                      NaN
# 379                                      NaN
#
#     Actions or Circumstances Prior to Crash Text Format  To or From School  \
# 2                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# 7                                                  NaN                 NaN
# 9                                     Crossing Roadway                 1.0
# 12                                                 NaN                 NaN
# ..                                                 ...                 ...
# 366                                                NaN                 NaN
# 367                                                NaN                 NaN
# 369                                                NaN                 NaN
# 376                                                NaN                 NaN
# 379                                                NaN                 NaN
#
#     To or From School Text Format  Actions or Circumstances At Time Of Crash  \
# 2                             NaN                                        NaN
# 4                             NaN                                        NaN
# 7                             NaN                                        NaN
# 9                              No                                       99.0
# 12                            NaN                                        NaN
# ..                            ...                                        ...
# 366                           NaN                                        NaN
# 367                           NaN                                        NaN
# 369                           NaN                                        NaN
# 376                           NaN                                        NaN
# 379                           NaN                                        NaN
#
#     Actions or Circumstances At Time Of Crash Text Format  \
# 2                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 9                                              Unknown
# 12                                                 NaN
# ..                                                 ...
# 366                                                NaN
# 367                                                NaN
# 369                                                NaN
# 376                                                NaN
# 379                                                NaN
#
#      Actions or Circumstances At Time Of Crash2  \
# 2                                           NaN
# 4                                           NaN
# 7                                           NaN
# 9                                           NaN
# 12                                          NaN
# ..                                          ...
# 366                                         NaN
# 367                                         NaN
# 369                                         NaN
# 376                                         NaN
# 379                                         NaN
#
#     Actions or Circumstances At Time Of Crash2 Text Format  \
# 2                                                  NaN
# 4                                                  NaN
# 7                                                  NaN
# 9                                                  NaN
# 12                                                 NaN
# ..                                                 ...
# 366                                                NaN
# 367                                                NaN
# 369                                                NaN
# 376                                                NaN
# 379                                                NaN
#
#      Location At Time Of Crash Location At Time Of Crash Text Format  \
# 2                          NaN                                   NaN
# 4                          NaN                                   NaN
# 7                          NaN                                   NaN
# 9                          5.0            Travel Lane-Other Location
# 12                         NaN                                   NaN
# ..                         ...                                   ...
# 366                        NaN                                   NaN
# 367                        NaN                                   NaN
# 369                        NaN                                   NaN
# 376                        NaN                                   NaN
# 379                        NaN                                   NaN
#
#      Safety Equipment Safety Equipment Text Format  Safety Equipment2  \
# 2                 NaN                          NaN                NaN
# 4                 NaN                          NaN                NaN
# 7                 NaN                          NaN                NaN
# 9                 0.0                         None                NaN
# 12                NaN                          NaN                NaN
# ..                ...                          ...                ...
# 366               NaN                          NaN                NaN
# 367               NaN                          NaN                NaN
# 369               NaN                          NaN                NaN
# 376               NaN                          NaN                NaN
# 379               NaN                          NaN                NaN
#
#     Safety Equipment2 Text Format  Non-motorist Distracted By  \
# 2                             NaN                         NaN
# 4                             NaN                         NaN
# 7                             NaN                         NaN
# 9                             NaN                        99.0
# 12                            NaN                         NaN
# ..                            ...                         ...
# 366                           NaN                         NaN
# 367                           NaN                         NaN
# 369                           NaN                         NaN
# 376                           NaN                         NaN
# 379                           NaN                         NaN
#
#     Non-motorist Distracted By Text Format  Seating Position  \
# 2                                      NaN              13.0
# 4                                      NaN              11.0
# 7                                      NaN              11.0
# 9                    Unknown if Distracted               NaN
# 12                                     NaN              11.0
# ..                                     ...               ...
# 366                                    NaN              11.0
# 367                                    NaN              11.0
# 369                                    NaN              11.0
# 376                                    NaN              11.0
# 379                                    NaN              11.0
#
#     Seating Position Text Format Seating Position for Bus             City  \
# 2          First Row, Right Seat                      NaN        Thomaston
# 4           First Row, Left Seat                      NaN          Milford
# 7           First Row, Left Seat                      NaN   North Franklin
# 9                            NaN                      NaN          Shelton
# 12          First Row, Left Seat                      NaN       Brookfield
# ..                           ...                      ...              ...
# 366         First Row, Left Seat                      NaN  Preston
# 367         First Row, Left Seat                      NaN      Jewett City
# 369         First Row, Left Seat                      NaN      Jewett City
# 376         First Row, Left Seat                      NaN          Milford
# 379         First Row, Left Seat                      NaN          Danbury
#
#           Country  Driver License Jurisdiction  \
# 2             NaN                          2.0
# 4    UnitedStates                          2.0
# 7             NaN                          2.0
# 9             NaN                         88.0
# 12            NaN                          2.0
# ..            ...                          ...
# 366           NaN                          2.0
# 367           NaN                          2.0
# 369           NaN                          2.0
# 376  UnitedStates                          2.0
# 379           NaN                          2.0
#
#     Driver License Jurisdiction Text Format Drivers License Issued By  \
# 2                                     State                        CT
# 4                                     State                        CT
# 7                                     State                        CT
# 9                            Not applicable                        CT
# 12                                    State                        CT
# ..                                      ...                       ...
# 366                                   State                        CT
# 367                                   State                        CT
# 369                                   State                        CT
# 376                                   State                        CT
# 379                                   State                        CT
#
#      Drivers License Class  Commercial License Class  \
# 2                      NaN                       NaN
# 4                      4.0                       1.0
# 7                      4.0                       1.0
# 9                      NaN                       NaN
# 12                     1.0                       NaN
# ..                     ...                       ...
# 366                    4.0                       1.0
# 367                    4.0                       1.0
# 369                    4.0                       1.0
# 376                    4.0                       1.0
# 379                    4.0                       1.0
#
#     Commercial License Class Text Format  \
# 2                                    NaN
# 4                                     No
# 7                                     No
# 9                                    NaN
# 12                                   NaN
# ..                                   ...
# 366                                   No
# 367                                   No
# 369                                   No
# 376                                   No
# 379                                   No
#
#      Transported to First Medical Facility By  \
# 2                                         1.0
# 4                                         1.0
# 7                                         3.0
# 9                                         3.0
# 12                                        3.0
# ..                                        ...
# 366                                       1.0
# 367                                       3.0
# 369                                       3.0
# 376                                       3.0
# 379                                       1.0
#
#     Transported to First Medical Facility By Text Format  \
# 2                                      Not Transported
# 4                                      Not Transported
# 7                                           EMS Ground
# 9                                           EMS Ground
# 12                                          EMS Ground
# ..                                                 ...
# 366                                    Not Transported
# 367                                         EMS Ground
# 369                                         EMS Ground
# 376                                         EMS Ground
# 379                                    Not Transported
#
#     Name of the EMS agency Name of the Intended Receiving Facility
# 2     Bristol Hospital EMS                             NEW BRITAIN
# 4                      NaN                                     NaN
# 7                      NaN                                     L&M
# 9      Echo Hose Ambulance                     BRIDGEPORT HOSPITAL
# 12                    NVAC                                 DANBURY
# ..                     ...                                     ...
# 366                   OCME                         OCME FARMINGTON
# 367                    NaN                         Backus Hospital
# 369                    NaN              William W. Backus Hospital
# 376           MILFORD FIRE                     BRIDGEPORT HOSPITAL
# 379                    NaN                                     NaN
#
# [146 rows x 83 columns]

# %%
# Set the display options to show all columns
pd.set_option('display.max_columns', None)

# Display the DataFrame
data
# Out:
#      CrashId  VehicleId  PersonId   Age  Gender Gender Text Format State  \
# 0    1120523        1.0         1  74.0       2             Female    CT
# 1    1120523        2.0         4  19.0       1               Male    CT
# 2    1120523        1.0         3  69.0       1               Male    CT
# 3    1120523        2.0         2  19.0       1               Male    CT
# 4    1120633        1.0         1  41.0       1               Male    CT
# ..       ...        ...       ...   ...     ...                ...   ...
# 375  1193880        NaN         6  38.0       2             Female    CT
# 376  1193880        2.0         2  65.0       1               Male    CT
# 377  1194778        2.0         2  56.0       1               Male    CT
# 378  1194778        NaN         3  31.0       2             Female    CT
# 379  1194778        1.0         1  20.0       1               Male    CT
#
#     Postal Code  Person Type Person Type Text Format Injury Status  \
# 0          6787            1                  Driver             C
# 1          6489            2               Passenger             C
# 2          6787            2               Passenger             K
# 3          6489            1                  Driver             O
# 4          6460            1                  Driver             K
# ..          ...          ...                     ...           ...
# 375        6516            9                 Witness           NaN
# 376        6460            1                  Driver             K
# 377        6810            1                  Driver             A
# 378        6811            9                 Witness           NaN
# 379        6811            1                  Driver             K
#
#         Injury Status Text Format  Condition at Time of Crash  \
# 0             Possible Injury (C)                         1.0
# 1             Possible Injury (C)                         NaN
# 2                Fatal Injury (K)                         NaN
# 3          No Apparent Injury (O)                         1.0
# 4                Fatal Injury (K)                         6.0
# ..                            ...                         ...
# 375                           NaN                         NaN
# 376              Fatal Injury (K)                        99.0
# 377  Suspected Serious Injury (A)                        99.0
# 378                           NaN                         NaN
# 379              Fatal Injury (K)                        97.0
#
#                Condition at Time of Crash Text Format  \
# 0                                   Apparently Normal
# 1                                                 NaN
# 2                                                 NaN
# 3                                   Apparently Normal
# 4    Under the Influence of Medications/Drugs/Alcohol
# ..                                                ...
# 375                                               NaN
# 376                                           Unknown
# 377                                           Unknown
# 378                                               NaN
# 379                                             Other
#
#      Condition at Time of Crash2  \
# 0                           88.0
# 1                            NaN
# 2                            NaN
# 3                           88.0
# 4                            6.0
# ..                           ...
# 375                          NaN
# 376                         99.0
# 377                         88.0
# 378                          NaN
# 379                         88.0
#
#               Condition at Time of Crash2 Text Format  \
# 0                                      Not Applicable
# 1                                                 NaN
# 2                                                 NaN
# 3                                      Not Applicable
# 4    Under the Influence of Medications/Drugs/Alcohol
# ..                                                ...
# 375                                               NaN
# 376                                           Unknown
# 377                                    Not Applicable
# 378                                               NaN
# 379                                    Not Applicable
#
#      Action Taken by Officer Action Taken by Officer Text Format  \
# 0                        2.0                     Written Warning
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
# 3                        0.0                          None taken
# 4                        4.0                      Arrest/Summons
# ..                       ...                                 ...
# 375                      NaN                                 NaN
# 376                      0.0                          None taken
# 377                      0.0                          None taken
# 378                      NaN                                 NaN
# 379                      0.0                          None taken
#
#      Alcohol Test Status Alcohol Test Status Text Format  \
# 0                    1.0                  Test Not Given
# 1                    1.0                  Test Not Given
# 2                    1.0                  Test Not Given
# 3                    1.0                  Test Not Given
# 4                    2.0                    Test Refused
# ..                   ...                             ...
# 375                  NaN                             NaN
# 376                  1.0                  Test Not Given
# 377                  1.0                  Test Not Given
# 378                  NaN                             NaN
# 379                  1.0                  Test Not Given
#
#      Type Of Alcohol Test Type Of Alcohol Test Text Format  Drug Test Status  \
# 0                    88.0                   Not Applicable               1.0
# 1                    88.0                   Not Applicable               1.0
# 2                    88.0                   Not Applicable               1.0
# 3                    88.0                   Not Applicable               1.0
# 4                     3.0                           Breath               2.0
# ..                    ...                              ...               ...
# 375                   NaN                              NaN               NaN
# 376                  88.0                   Not Applicable               1.0
# 377                  88.0                   Not Applicable               1.0
# 378                   NaN                              NaN               NaN
# 379                  88.0                   Not Applicable               1.0
#
#     Drug Test Status Text Format  Type Of Drig Test  \
# 0                 Test Not Given               88.0
# 1                 Test Not Given               88.0
# 2                 Test Not Given               88.0
# 3                 Test Not Given               88.0
# 4                   Test Refused                2.0
# ..                           ...                ...
# 375                          NaN                NaN
# 376               Test Not Given               88.0
# 377               Test Not Given               88.0
# 378                          NaN                NaN
# 379               Test Not Given               88.0
#
#     Type Of Drig Test Text Format  Ejection Status  \
# 0                  Not Applicable              1.0
# 1                  Not Applicable              1.0
# 2                  Not Applicable              1.0
# 3                  Not Applicable              1.0
# 4                           Urine              1.0
# ..                            ...              ...
# 375                           NaN              NaN
# 376                Not Applicable              1.0
# 377                Not Applicable              1.0
# 378                           NaN              NaN
# 379                Not Applicable              1.0
#
#     Ejection Status Text Format  Restraint System  \
# 0                   Not Ejected               1.0
# 1                   Not Ejected               1.0
# 2                   Not Ejected               1.0
# 3                   Not Ejected               1.0
# 4                   Not Ejected               1.0
# ..                          ...               ...
# 375                         NaN               NaN
# 376                 Not Ejected              88.0
# 377                 Not Ejected               0.0
# 378                         NaN               NaN
# 379                 Not Ejected               0.0
#
#          Restraint System Text Format  Helmet Use Helmet Use Text Format  \
# 0          Shoulder and Lap Belt Used        88.0         Not Applicable
# 1          Shoulder and Lap Belt Used        88.0         Not Applicable
# 2          Shoulder and Lap Belt Used        88.0         Not Applicable
# 3          Shoulder and Lap Belt Used        88.0         Not Applicable
# 4          Shoulder and Lap Belt Used        88.0         Not Applicable
# ..                                ...         ...                    ...
# 375                               NaN         NaN                    NaN
# 376                    Not Applicable         1.0              No Helmet
# 377  None Used-Motor Vehicle Occupant        88.0         Not Applicable
# 378                               NaN         NaN                    NaN
# 379  None Used-Motor Vehicle Occupant        88.0         Not Applicable
#
#      Air Bag Status Air Bag Status Text Format  Speeding Related  \
# 0               2.0             Deployed-Front               1.0
# 1               2.0             Deployed-Front               NaN
# 2               2.0             Deployed-Front               NaN
# 3               2.0             Deployed-Front               1.0
# 4               2.0             Deployed-Front               1.0
# ..              ...                        ...               ...
# 375             NaN                        NaN               NaN
# 376            88.0             Not applicable               1.0
# 377             6.0       Deployed-Combination               1.0
# 378             NaN                        NaN               NaN
# 379             6.0       Deployed-Combination               3.0
#
#     Speeding Related Text Format  Driver Actions 1  \
# 0                             No               3.0
# 1                            NaN              88.0
# 2                            NaN              88.0
# 3                             No               1.0
# 4                             No               2.0
# ..                           ...               ...
# 375                          NaN               NaN
# 376                           No               1.0
# 377                           No               1.0
# 378                          NaN               NaN
# 379         Exceeded Speed Limit              13.0
#
#       Driver Actions 1 Text Format  Driver Actions 2  \
# 0     Failed to Yield Right-of-Way              88.0
# 1                   Not Applicable              88.0
# 2                   Not Applicable              88.0
# 3           No Contributing Action              88.0
# 4                  Ran Off Roadway              88.0
# ..                             ...               ...
# 375                            NaN               NaN
# 376         No Contributing Action              88.0
# 377         No Contributing Action              88.0
# 378                            NaN               NaN
# 379  Failed to Keep in Proper Lane              14.0
#
#                           Driver Actions 2 Text Format  Driver Actions 3  \
# 0                                       Not Applicable              88.0
# 1                                       Not Applicable              88.0
# 2                                       Not Applicable              88.0
# 3                                       Not Applicable              88.0
# 4                                       Not Applicable              88.0
# ..                                                 ...               ...
# 375                                                NaN               NaN
# 376                                     Not Applicable              88.0
# 377                                     Not Applicable              88.0
# 378                                                NaN               NaN
# 379  Operated Motor Vehicle in Reckless or Aggressi...              88.0
#
#     Driver Actions 3 Text Format  Driver Actions 4  \
# 0                 Not Applicable              88.0
# 1                 Not Applicable              88.0
# 2                 Not Applicable              88.0
# 3                 Not Applicable              88.0
# 4                 Not Applicable              88.0
# ..                           ...               ...
# 375                          NaN               NaN
# 376               Not Applicable              88.0
# 377               Not Applicable              88.0
# 378                          NaN               NaN
# 379               Not Applicable              88.0
#
#     Driver Actions 4 Text Format  Driver Distracted By  \
# 0                 Not Applicable                  99.0
# 1                 Not Applicable                   NaN
# 2                 Not Applicable                   NaN
# 3                 Not Applicable                  99.0
# 4                 Not Applicable                   1.0
# ..                           ...                   ...
# 375                          NaN                   NaN
# 376               Not Applicable                  99.0
# 377               Not Applicable                   1.0
# 378                          NaN                   NaN
# 379               Not Applicable                  99.0
#
#     Driver Distracted By Text Format  \
# 0              Unknown if Distracted
# 1                                NaN
# 2                                NaN
# 3              Unknown if Distracted
# 4                     Not Distracted
# ..                               ...
# 375                              NaN
# 376            Unknown if Distracted
# 377                   Not Distracted
# 378                              NaN
# 379            Unknown if Distracted
#
#     Roadway On Which Nonmotorist Was Traveling/Located  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
#
#     Direction nonmotorist was traveling Direction Unknown  \
# 0                                   NaN               NaN
# 1                                   NaN               NaN
# 2                                   NaN               NaN
# 3                                   NaN               NaN
# 4                                   NaN               NaN
# ..                                  ...               ...
# 375                                 NaN               NaN
# 376                                 NaN               NaN
# 377                                 NaN               NaN
# 378                                 NaN               NaN
# 379                                 NaN               NaN
#
#      Striking Motor Vehicle ID  Bicycle ID Non-Motorist Not In Roadway  \
# 0                          NaN         NaN                         NaN
# 1                          NaN         NaN                         NaN
# 2                          NaN         NaN                         NaN
# 3                          NaN         NaN                         NaN
# 4                          NaN         NaN                         NaN
# ..                         ...         ...                         ...
# 375                        NaN         NaN                         NaN
# 376                        NaN         NaN                         NaN
# 377                        NaN         NaN                         NaN
# 378                        NaN         NaN                         NaN
# 379                        NaN         NaN                         NaN
#
#      Actions or Circumstances Prior to Crash  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 375                                      NaN
# 376                                      NaN
# 377                                      NaN
# 378                                      NaN
# 379                                      NaN
#
#     Actions or Circumstances Prior to Crash Text Format  To or From School  \
# 0                                                  NaN                 NaN
# 1                                                  NaN                 NaN
# 2                                                  NaN                 NaN
# 3                                                  NaN                 NaN
# 4                                                  NaN                 NaN
# ..                                                 ...                 ...
# 375                                                NaN                 NaN
# 376                                                NaN                 NaN
# 377                                                NaN                 NaN
# 378                                                NaN                 NaN
# 379                                                NaN                 NaN
#
#     To or From School Text Format  Actions or Circumstances At Time Of Crash  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
# 4                             NaN                                        NaN
# ..                            ...                                        ...
# 375                           NaN                                        NaN
# 376                           NaN                                        NaN
# 377                           NaN                                        NaN
# 378                           NaN                                        NaN
# 379                           NaN                                        NaN
#
#     Actions or Circumstances At Time Of Crash Text Format  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
#
#      Actions or Circumstances At Time Of Crash2  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 375                                         NaN
# 376                                         NaN
# 377                                         NaN
# 378                                         NaN
# 379                                         NaN
#
#     Actions or Circumstances At Time Of Crash2 Text Format  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 375                                                NaN
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
#
#      Location At Time Of Crash Location At Time Of Crash Text Format  \
# 0                          NaN                                   NaN
# 1                          NaN                                   NaN
# 2                          NaN                                   NaN
# 3                          NaN                                   NaN
# 4                          NaN                                   NaN
# ..                         ...                                   ...
# 375                        NaN                                   NaN
# 376                        NaN                                   NaN
# 377                        NaN                                   NaN
# 378                        NaN                                   NaN
# 379                        NaN                                   NaN
#
#      Safety Equipment Safety Equipment Text Format  Safety Equipment2  \
# 0                 NaN                          NaN                NaN
# 1                 NaN                          NaN                NaN
# 2                 NaN                          NaN                NaN
# 3                 NaN                          NaN                NaN
# 4                 NaN                          NaN                NaN
# ..                ...                          ...                ...
# 375               NaN                          NaN                NaN
# 376               NaN                          NaN                NaN
# 377               NaN                          NaN                NaN
# 378               NaN                          NaN                NaN
# 379               NaN                          NaN                NaN
#
#     Safety Equipment2 Text Format  Non-motorist Distracted By  \
# 0                             NaN                         NaN
# 1                             NaN                         NaN
# 2                             NaN                         NaN
# 3                             NaN                         NaN
# 4                             NaN                         NaN
# ..                            ...                         ...
# 375                           NaN                         NaN
# 376                           NaN                         NaN
# 377                           NaN                         NaN
# 378                           NaN                         NaN
# 379                           NaN                         NaN
#
#     Non-motorist Distracted By Text Format  Seating Position  \
# 0                                      NaN              11.0
# 1                                      NaN              13.0
# 2                                      NaN              13.0
# 3                                      NaN              11.0
# 4                                      NaN              11.0
# ..                                     ...               ...
# 375                                    NaN               NaN
# 376                                    NaN              11.0
# 377                                    NaN              11.0
# 378                                    NaN               NaN
# 379                                    NaN              11.0
#
#     Seating Position Text Format Seating Position for Bus         City  \
# 0           First Row, Left Seat                      NaN    Thomaston
# 1          First Row, Right Seat                      NaN  Southington
# 2          First Row, Right Seat                      NaN    Thomaston
# 3           First Row, Left Seat                      NaN  Southington
# 4           First Row, Left Seat                      NaN      Milford
# ..                           ...                      ...          ...
# 375                          NaN                      NaN   West Haven
# 376         First Row, Left Seat                      NaN      Milford
# 377         First Row, Left Seat                      NaN      Danbury
# 378                          NaN                      NaN      Danbury
# 379         First Row, Left Seat                      NaN      Danbury
#
#           Country  Driver License Jurisdiction  \
# 0             NaN                          2.0
# 1             NaN                          2.0
# 2             NaN                          2.0
# 3             NaN                          2.0
# 4    UnitedStates                          2.0
# ..            ...                          ...
# 375  UnitedStates                          NaN
# 376  UnitedStates                          2.0
# 377           NaN                          2.0
# 378  UnitedStates                          NaN
# 379           NaN                          2.0
#
#     Driver License Jurisdiction Text Format Drivers License Issued By  \
# 0                                     State                        CT
# 1                                     State                        CT
# 2                                     State                        CT
# 3                                     State                        CT
# 4                                     State                        CT
# ..                                      ...                       ...
# 375                                     NaN                       NaN
# 376                                   State                        CT
# 377                                   State                        CT
# 378                                     NaN                        CT
# 379                                   State                        CT
#
#      Drivers License Class  Commercial License Class  \
# 0                      4.0                       1.0
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      4.0                       1.0
# 4                      4.0                       1.0
# ..                     ...                       ...
# 375                    NaN                       NaN
# 376                    4.0                       1.0
# 377                    4.0                       1.0
# 378                    NaN                       NaN
# 379                    4.0                       1.0
#
#     Commercial License Class Text Format  \
# 0                                     No
# 1                                    NaN
# 2                                    NaN
# 3                                     No
# 4                                     No
# ..                                   ...
# 375                                  NaN
# 376                                   No
# 377                                   No
# 378                                  NaN
# 379                                   No
#
#      Transported to First Medical Facility By  \
# 0                                         1.0
# 1                                         1.0
# 2                                         1.0
# 3                                         1.0
# 4                                         1.0
# ..                                        ...
# 375                                       NaN
# 376                                       3.0
# 377                                       3.0
# 378                                       NaN
# 379                                       1.0
#
#     Transported to First Medical Facility By Text Format  \
# 0                                      Not Transported
# 1                                      Not Transported
# 2                                      Not Transported
# 3                                      Not Transported
# 4                                      Not Transported
# ..                                                 ...
# 375                                                NaN
# 376                                         EMS Ground
# 377                                         EMS Ground
# 378                                                NaN
# 379                                    Not Transported
#
#          Name of the EMS agency Name of the Intended Receiving Facility
# 0          Bristol Hospital EMS                             NEW BRITAIN
# 1          Bristol Hospital EMS                             NEW BRITAIN
# 2          Bristol Hospital EMS                             NEW BRITAIN
# 3                           NaN                                     NaN
# 4                           NaN                                     NaN
# ..                          ...                                     ...
# 375                         NaN                                     NaN
# 376                MILFORD FIRE                     BRIDGEPORT HOSPITAL
# 377  Ridgefield Fire Department                        Danbury Hospital
# 378                         NaN                                     NaN
# 379                         NaN                                     NaN
#
# [380 rows x 83 columns]

# %% [markdown]
# ## 2) Filtering the data
# Now we only have the information of the people who were killed in the crashes.

# %% [markdown]
# I am going to see how many were drivers, how many were passengers, how many were pedestrians. I will also filter to see the most common age of those who were killed and the gender.

# %%
# Load the newly uploaded dataset to ensure accuracy
fatal_injury_k_data_path = 'fatal_injury_k_data.csv'
fatal_injury_k_data = pd.read_csv(fatal_injury_k_data_path)

# Count the number of drivers, passengers, and pedestrians
driver_count = fatal_injury_k_data[fatal_injury_k_data['Person Type Text Format'] == 'Driver'].shape[0]
passenger_count = fatal_injury_k_data[fatal_injury_k_data['Person Type Text Format'] == 'Passenger'].shape[0]
pedestrian_count = fatal_injury_k_data[fatal_injury_k_data['Person Type Text Format'] == 'Pedestrian'].shape[0]

# Most common Age
most_common_age = fatal_injury_k_data['Age'].mode()[0]

# Most common Gender Text
most_common_gender_text = fatal_injury_k_data['Gender Text Format'].mode()[0]

driver_count, passenger_count, pedestrian_count, most_common_age, most_common_gender_text
# Out:
# (95, 22, 29, 23.0, 'Male')

# %% [markdown]
# Here are the details from the dataset:
#
# Number of Drivers: 95
# Number of Passengers: 22
# Number of Pedestrians: 29
# Most Common Age: 23 years old
# Most Common Gender Text: Male

# %%
count_23_male = fatal_injury_k_data[(fatal_injury_k_data['Age'] == 23) & (fatal_injury_k_data['Gender Text Format'] == 'Male')].shape[0]

count_23_male
# Out:
# 3

# %% [markdown]
# I also want to see how many people were killed in DUI accidents (Under the Influence of Medications/Drugs/Alcohol)

# %%
# Filter the data where "Condition at Time of Crash Text Format" is "Under the Influence of Medications/Drugs/Alcohol"
under_influence_data = fatal_injury_k_data[fatal_injury_k_data['Condition at Time of Crash Text Format'] == 'Under the Influence of Medications/Drugs/Alcohol']

# Display the filtered data
under_influence_data
# Out:
#      CrashId  VehicleId  PersonId   Age  Gender Gender Text Format State  \
# 1    1120633        1.0         1  41.0       1               Male    CT
# 50   1151133        1.0         1  21.0       1               Male    CT
# 65   1156862        2.0         2  41.0       1               Male    CT
# 86   1167603        NaN         3  28.0       1               Male    NY
# 89   1168442        1.0         1  45.0       1               Male    CT
# 94   1172071        2.0         2  44.0       1               Male    CT
# 106  1176111        1.0         1  20.0       1               Male    CT
# 109  1176923        1.0         1  44.0       1               Male    CT
# 111  1177256        1.0         1  68.0       1               Male    CT
# 116  1185305        1.0         1  23.0       2             Female    CT
# 117  1185306        NaN         2  46.0       1               Male    CT
# 120  1186364        NaN         3  40.0       1               Male    CT
# 133  1192332        1.0         1  25.0       1               Male    CT
# 139  1193112        1.0         1  34.0       2             Female    CT
#
#     Postal Code  Person Type Person Type Text Format Injury Status  \
# 1          6460            1                  Driver             K
# 50         6606            1                  Driver             K
# 65         6420            1                  Driver             K
# 86        11221            3              Pedestrian             K
# 89         6331            1                  Driver             K
# 94         6052            1                  Driver             K
# 106        6118            1                  Driver             K
# 109        6511            1                  Driver             K
# 111        6420            1                  Driver             K
# 116        6706            1                  Driver             K
# 117        6702            3              Pedestrian             K
# 120         NaN            3              Pedestrian             K
# 133        6401            1                  Driver             K
# 139        6360            1                  Driver             K
#
#     Injury Status Text Format  Condition at Time of Crash  \
# 1            Fatal Injury (K)                         6.0
# 50           Fatal Injury (K)                         6.0
# 65           Fatal Injury (K)                         6.0
# 86           Fatal Injury (K)                         6.0
# 89           Fatal Injury (K)                         6.0
# 94           Fatal Injury (K)                         6.0
# 106          Fatal Injury (K)                         6.0
# 109          Fatal Injury (K)                         6.0
# 111          Fatal Injury (K)                         6.0
# 116          Fatal Injury (K)                         6.0
# 117          Fatal Injury (K)                         6.0
# 120          Fatal Injury (K)                         6.0
# 133          Fatal Injury (K)                         6.0
# 139          Fatal Injury (K)                         6.0
#
#                Condition at Time of Crash Text Format  \
# 1    Under the Influence of Medications/Drugs/Alcohol
# 50   Under the Influence of Medications/Drugs/Alcohol
# 65   Under the Influence of Medications/Drugs/Alcohol
# 86   Under the Influence of Medications/Drugs/Alcohol
# 89   Under the Influence of Medications/Drugs/Alcohol
# 94   Under the Influence of Medications/Drugs/Alcohol
# 106  Under the Influence of Medications/Drugs/Alcohol
# 109  Under the Influence of Medications/Drugs/Alcohol
# 111  Under the Influence of Medications/Drugs/Alcohol
# 116  Under the Influence of Medications/Drugs/Alcohol
# 117  Under the Influence of Medications/Drugs/Alcohol
# 120  Under the Influence of Medications/Drugs/Alcohol
# 133  Under the Influence of Medications/Drugs/Alcohol
# 139  Under the Influence of Medications/Drugs/Alcohol
#
#      Condition at Time of Crash2  \
# 1                            6.0
# 50                          88.0
# 65                          88.0
# 86                          88.0
# 89                          88.0
# 94                          88.0
# 106                         88.0
# 109                         88.0
# 111                         99.0
# 116                         88.0
# 117                         88.0
# 120                         88.0
# 133                          NaN
# 139                         88.0
#
#               Condition at Time of Crash2 Text Format  \
# 1    Under the Influence of Medications/Drugs/Alcohol
# 50                                     Not Applicable
# 65                                     Not Applicable
# 86                                     Not Applicable
# 89                                     Not Applicable
# 94                                     Not Applicable
# 106                                    Not Applicable
# 109                                    Not Applicable
# 111                                           Unknown
# 116                                    Not Applicable
# 117                                    Not Applicable
# 120                                    Not Applicable
# 133                                               NaN
# 139                                    Not Applicable
#
#      Action Taken by Officer Action Taken by Officer Text Format  \
# 1                        4.0                      Arrest/Summons
# 50                       0.0                          None taken
# 65                       0.0                          None taken
# 86                       0.0                          None taken
# 89                       0.0                          None taken
# 94                       0.0                          None taken
# 106                      0.0                          None taken
# 109                      0.0                          None taken
# 111                      0.0                          None taken
# 116                      0.0                          None taken
# 117                      0.0                          None taken
# 120                      0.0                          None taken
# 133                      0.0                          None taken
# 139                      0.0                          None taken
#
#      Alcohol Test Status Alcohol Test Status Text Format  \
# 1                    2.0                    Test Refused
# 50                   3.0                      Test Given
# 65                   3.0                      Test Given
# 86                   1.0                  Test Not Given
# 89                   3.0                      Test Given
# 94                   3.0                      Test Given
# 106                  3.0                      Test Given
# 109                  3.0                      Test Given
# 111                  3.0                      Test Given
# 116                  1.0                  Test Not Given
# 117                  3.0                      Test Given
# 120                  1.0                  Test Not Given
# 133                  1.0                  Test Not Given
# 139                  3.0                      Test Given
#
#      Type Of Alcohol Test Type Of Alcohol Test Text Format  Drug Test Status  \
# 1                     3.0                           Breath               2.0
# 50                    1.0                            Blood               3.0
# 65                    1.0                            Blood               3.0
# 86                   88.0                   Not Applicable               1.0
# 89                    1.0                            Blood               1.0
# 94                    1.0                            Blood               3.0
# 106                   1.0                            Blood               3.0
# 109                  97.0                            Other               3.0
# 111                   1.0                            Blood               3.0
# 116                  88.0                   Not Applicable               1.0
# 117                  97.0                            Other               3.0
# 120                  88.0                   Not Applicable               1.0
# 133                  88.0                   Not Applicable               1.0
# 139                   1.0                            Blood               3.0
#
#     Drug Test Status Text Format  Type Of Drig Test  \
# 1                   Test Refused                2.0
# 50                    Test Given                1.0
# 65                    Test Given                1.0
# 86                Test Not Given               88.0
# 89                Test Not Given               88.0
# 94                    Test Given                1.0
# 106                   Test Given                1.0
# 109                   Test Given               97.0
# 111                   Test Given                1.0
# 116               Test Not Given               88.0
# 117                   Test Given               97.0
# 120               Test Not Given               88.0
# 133               Test Not Given               88.0
# 139                   Test Given                1.0
#
#     Type Of Drig Test Text Format  Ejection Status  \
# 1                           Urine              1.0
# 50                          Blood              1.0
# 65                          Blood              1.0
# 86                 Not Applicable              NaN
# 89                 Not Applicable              1.0
# 94                          Blood              1.0
# 106                         Blood              1.0
# 109                         Other              1.0
# 111                         Blood              1.0
# 116                Not Applicable              1.0
# 117                         Other              NaN
# 120                Not Applicable              NaN
# 133                Not Applicable             88.0
# 139                         Blood              1.0
#
#     Ejection Status Text Format  Restraint System  \
# 1                   Not Ejected               1.0
# 50                  Not Ejected               1.0
# 65                  Not Ejected               0.0
# 86                          NaN               NaN
# 89                  Not Ejected              88.0
# 94                  Not Ejected               0.0
# 106                 Not Ejected               1.0
# 109                 Not Ejected               1.0
# 111                 Not Ejected               0.0
# 116                 Not Ejected               0.0
# 117                         NaN               NaN
# 120                         NaN               NaN
# 133              Not Applicable              88.0
# 139                 Not Ejected               0.0
#
#          Restraint System Text Format  Helmet Use  \
# 1          Shoulder and Lap Belt Used        88.0
# 50         Shoulder and Lap Belt Used        88.0
# 65   None Used-Motor Vehicle Occupant        88.0
# 86                                NaN         NaN
# 89                     Not Applicable         2.0
# 94   None Used-Motor Vehicle Occupant        88.0
# 106        Shoulder and Lap Belt Used        88.0
# 109        Shoulder and Lap Belt Used        88.0
# 111  None Used-Motor Vehicle Occupant        88.0
# 116  None Used-Motor Vehicle Occupant        88.0
# 117                               NaN         NaN
# 120                               NaN         NaN
# 133                    Not Applicable         1.0
# 139  None Used-Motor Vehicle Occupant        88.0
#
#               Helmet Use Text Format  Air Bag Status  \
# 1                     Not Applicable             2.0
# 50                    Not Applicable             6.0
# 65                    Not Applicable             6.0
# 86                               NaN             NaN
# 89   DOT-Compliant Motorcycle Helmet            88.0
# 94                    Not Applicable             6.0
# 106                   Not Applicable            99.0
# 109                   Not Applicable             6.0
# 111                   Not Applicable             6.0
# 116                   Not Applicable             2.0
# 117                              NaN             NaN
# 120                              NaN             NaN
# 133                        No Helmet             1.0
# 139                   Not Applicable             6.0
#
#     Air Bag Status Text Format  Speeding Related Speeding Related Text Format  \
# 1               Deployed-Front               1.0                           No
# 50        Deployed-Combination               1.0                           No
# 65        Deployed-Combination               1.0                           No
# 86                         NaN               NaN                          NaN
# 89              Not applicable              99.0                      Unknown
# 94        Deployed-Combination               3.0         Exceeded Speed Limit
# 106                    Unknown               3.0         Exceeded Speed Limit
# 109       Deployed-Combination               3.0         Exceeded Speed Limit
# 111       Deployed-Combination               3.0         Exceeded Speed Limit
# 116             Deployed-Front              99.0                      Unknown
# 117                        NaN               NaN                          NaN
# 120                        NaN               NaN                          NaN
# 133               Not Deployed              99.0                      Unknown
# 139       Deployed-Combination               3.0         Exceeded Speed Limit
#
#      Driver Actions 1                       Driver Actions 1 Text Format  \
# 1                 2.0                                    Ran Off Roadway
# 50                2.0                                    Ran Off Roadway
# 65                3.0                       Failed to Yield Right-of-Way
# 86                NaN                                                NaN
# 89                2.0                                    Ran Off Roadway
# 94               12.0                               Followed Too Closely
# 106               2.0                                    Ran Off Roadway
# 109               2.0                                    Ran Off Roadway
# 111              14.0  Operated Motor Vehicle in Reckless or Aggressi...
# 116              15.0  Operated Motor Vehicle in Inattentive, Careles...
# 117               NaN                                                NaN
# 120               NaN                                                NaN
# 133               2.0                                    Ran Off Roadway
# 139              13.0                      Failed to Keep in Proper Lane
#
#      Driver Actions 2                       Driver Actions 2 Text Format  \
# 1                88.0                                     Not Applicable
# 50               88.0                                     Not Applicable
# 65               88.0                                     Not Applicable
# 86                NaN                                                NaN
# 89               88.0                                     Not Applicable
# 94               88.0                                     Not Applicable
# 106              14.0  Operated Motor Vehicle in Reckless or Aggressi...
# 109              15.0  Operated Motor Vehicle in Inattentive, Careles...
# 111               2.0                                    Ran Off Roadway
# 116              14.0  Operated Motor Vehicle in Reckless or Aggressi...
# 117               NaN                                                NaN
# 120               NaN                                                NaN
# 133              88.0                                     Not Applicable
# 139              88.0                                     Not Applicable
#
#      Driver Actions 3 Driver Actions 3 Text Format  Driver Actions 4  \
# 1                88.0               Not Applicable              88.0
# 50               88.0               Not Applicable              88.0
# 65               88.0               Not Applicable              88.0
# 86                NaN                          NaN               NaN
# 89               88.0               Not Applicable              88.0
# 94               88.0               Not Applicable              88.0
# 106              88.0               Not Applicable              88.0
# 109              88.0               Not Applicable              88.0
# 111              97.0    Other Contributing Action              88.0
# 116              88.0               Not Applicable              88.0
# 117               NaN                          NaN               NaN
# 120               NaN                          NaN               NaN
# 133              88.0               Not Applicable              88.0
# 139              88.0               Not Applicable              88.0
#
#     Driver Actions 4 Text Format  Driver Distracted By  \
# 1                 Not Applicable                   1.0
# 50                Not Applicable                  99.0
# 65                Not Applicable                   1.0
# 86                           NaN                   NaN
# 89                Not Applicable                  99.0
# 94                Not Applicable                  99.0
# 106               Not Applicable                  99.0
# 109               Not Applicable                   1.0
# 111               Not Applicable                  99.0
# 116               Not Applicable                  99.0
# 117                          NaN                   NaN
# 120                          NaN                   NaN
# 133               Not Applicable                  99.0
# 139               Not Applicable                   1.0
#
#     Driver Distracted By Text Format  \
# 1                     Not Distracted
# 50             Unknown if Distracted
# 65                    Not Distracted
# 86                               NaN
# 89             Unknown if Distracted
# 94             Unknown if Distracted
# 106            Unknown if Distracted
# 109                   Not Distracted
# 111            Unknown if Distracted
# 116            Unknown if Distracted
# 117                              NaN
# 120                              NaN
# 133            Unknown if Distracted
# 139                   Not Distracted
#
#     Roadway On Which Nonmotorist Was Traveling/Located  \
# 1                                                  NaN
# 50                                                 NaN
# 65                                                 NaN
# 86                                       Interstate 84
# 89                                                 NaN
# 94                                                 NaN
# 106                                                NaN
# 109                                                NaN
# 111                                                NaN
# 116                                                NaN
# 117                                      East Main St.
# 120                                   Boston Post Road
# 133                                                NaN
# 139                                                NaN
#
#     Direction nonmotorist was traveling Direction Unknown  \
# 1                                   NaN               NaN
# 50                                  NaN               NaN
# 65                                  NaN               NaN
# 86                                    W             False
# 89                                  NaN               NaN
# 94                                  NaN               NaN
# 106                                 NaN               NaN
# 109                                 NaN               NaN
# 111                                 NaN               NaN
# 116                                 NaN               NaN
# 117                                   N             False
# 120                                   W             False
# 133                                 NaN               NaN
# 139                                 NaN               NaN
#
#      Striking Motor Vehicle ID  Bicycle ID Non-Motorist Not In Roadway  \
# 1                          NaN         NaN                         NaN
# 50                         NaN         NaN                         NaN
# 65                         NaN         NaN                         NaN
# 86                         1.0         NaN                       False
# 89                         NaN         NaN                         NaN
# 94                         NaN         NaN                         NaN
# 106                        NaN         NaN                         NaN
# 109                        NaN         NaN                         NaN
# 111                        NaN         NaN                         NaN
# 116                        NaN         NaN                         NaN
# 117                        1.0         NaN                       False
# 120                        1.0         NaN                       False
# 133                        NaN         NaN                         NaN
# 139                        NaN         NaN                         NaN
#
#      Actions or Circumstances Prior to Crash  \
# 1                                        NaN
# 50                                       NaN
# 65                                       NaN
# 86                                      99.0
# 89                                       NaN
# 94                                       NaN
# 106                                      NaN
# 109                                      NaN
# 111                                      NaN
# 116                                      NaN
# 117                                      1.0
# 120                                      1.0
# 133                                      NaN
# 139                                      NaN
#
#     Actions or Circumstances Prior to Crash Text Format  To or From School  \
# 1                                                  NaN                 NaN
# 50                                                 NaN                 NaN
# 65                                                 NaN                 NaN
# 86                                             Unknown                 1.0
# 89                                                 NaN                 NaN
# 94                                                 NaN                 NaN
# 106                                                NaN                 NaN
# 109                                                NaN                 NaN
# 111                                                NaN                 NaN
# 116                                                NaN                 NaN
# 117                                   Crossing Roadway                 1.0
# 120                                   Crossing Roadway                 1.0
# 133                                                NaN                 NaN
# 139                                                NaN                 NaN
#
#     To or From School Text Format  Actions or Circumstances At Time Of Crash  \
# 1                             NaN                                        NaN
# 50                            NaN                                        NaN
# 65                            NaN                                        NaN
# 86                             No                                        5.0
# 89                            NaN                                        NaN
# 94                            NaN                                        NaN
# 106                           NaN                                        NaN
# 109                           NaN                                        NaN
# 111                           NaN                                        NaN
# 116                           NaN                                        NaN
# 117                            No                                        9.0
# 120                            No                                        9.0
# 133                           NaN                                        NaN
# 139                           NaN                                        NaN
#
#     Actions or Circumstances At Time Of Crash Text Format  \
# 1                                                  NaN
# 50                                                 NaN
# 65                                                 NaN
# 86   In Roadway Improperly (Standing, Lying, Workin...
# 89                                                 NaN
# 94                                                 NaN
# 106                                                NaN
# 109                                                NaN
# 111                                                NaN
# 116                                                NaN
# 117     Not Visible (Dark Clothing, No Lighting, etc.)
# 120     Not Visible (Dark Clothing, No Lighting, etc.)
# 133                                                NaN
# 139                                                NaN
#
#      Actions or Circumstances At Time Of Crash2  \
# 1                                           NaN
# 50                                          NaN
# 65                                          NaN
# 86                                         88.0
# 89                                          NaN
# 94                                          NaN
# 106                                         NaN
# 109                                         NaN
# 111                                         NaN
# 116                                         NaN
# 117                                        97.0
# 120                                         3.0
# 133                                         NaN
# 139                                         NaN
#
#     Actions or Circumstances At Time Of Crash2 Text Format  \
# 1                                                  NaN
# 50                                                 NaN
# 65                                                 NaN
# 86                                      Not Applicable
# 89                                                 NaN
# 94                                                 NaN
# 106                                                NaN
# 109                                                NaN
# 111                                                NaN
# 116                                                NaN
# 117                                              Other
# 120                      Failure to Yield Right-Of-Way
# 133                                                NaN
# 139                                                NaN
#
#      Location At Time Of Crash Location At Time Of Crash Text Format  \
# 1                          NaN                                   NaN
# 50                         NaN                                   NaN
# 65                         NaN                                   NaN
# 86                         5.0            Travel Lane-Other Location
# 89                         NaN                                   NaN
# 94                         NaN                                   NaN
# 106                        NaN                                   NaN
# 109                        NaN                                   NaN
# 111                        NaN                                   NaN
# 116                        NaN                                   NaN
# 117                        5.0            Travel Lane-Other Location
# 120                        5.0            Travel Lane-Other Location
# 133                        NaN                                   NaN
# 139                        NaN                                   NaN
#
#      Safety Equipment Safety Equipment Text Format  Safety Equipment2  \
# 1                 NaN                          NaN                NaN
# 50                NaN                          NaN                NaN
# 65                NaN                          NaN                NaN
# 86                0.0                         None               88.0
# 89                NaN                          NaN                NaN
# 94                NaN                          NaN                NaN
# 106               NaN                          NaN                NaN
# 109               NaN                          NaN                NaN
# 111               NaN                          NaN                NaN
# 116               NaN                          NaN                NaN
# 117               0.0                         None                0.0
# 120               0.0                         None                NaN
# 133               NaN                          NaN                NaN
# 139               NaN                          NaN                NaN
#
#     Safety Equipment2 Text Format  Non-motorist Distracted By  \
# 1                             NaN                         NaN
# 50                            NaN                         NaN
# 65                            NaN                         NaN
# 86                 Not Applicable                        99.0
# 89                            NaN                         NaN
# 94                            NaN                         NaN
# 106                           NaN                         NaN
# 109                           NaN                         NaN
# 111                           NaN                         NaN
# 116                           NaN                         NaN
# 117                          None                        99.0
# 120                           NaN                        99.0
# 133                           NaN                         NaN
# 139                           NaN                         NaN
#
#     Non-motorist Distracted By Text Format  Seating Position  \
# 1                                      NaN              11.0
# 50                                     NaN              11.0
# 65                                     NaN              11.0
# 86                   Unknown if Distracted               NaN
# 89                                     NaN              11.0
# 94                                     NaN              11.0
# 106                                    NaN              11.0
# 109                                    NaN              11.0
# 111                                    NaN              11.0
# 116                                    NaN              11.0
# 117                  Unknown if Distracted               NaN
# 120                  Unknown if Distracted               NaN
# 133                                    NaN              11.0
# 139                                    NaN              11.0
#
#     Seating Position Text Format  Seating Position for Bus           City  \
# 1           First Row, Left Seat                       NaN        Milford
# 50          First Row, Left Seat                       NaN     Bridgeport
# 65          First Row, Left Seat                       NaN          Salem
# 86                           NaN                       NaN       Brooklyn
# 89          First Row, Left Seat                       NaN     Canterbury
# 94          First Row, Left Seat                       NaN    New Britain
# 106         First Row, Left Seat                       NaN  East Hartford
# 109         First Row, Left Seat                       NaN      New Haven
# 111         First Row, Left Seat                       NaN          Salem
# 116         First Row, Left Seat                       NaN      Waterbury
# 117                          NaN                       NaN      Waterbury
# 120                          NaN                       NaN      New Haven
# 133         First Row, Left Seat                       NaN        Ansonia
# 139         First Row, Left Seat                       NaN        Norwich
#
#           Country  Driver License Jurisdiction  \
# 1    UnitedStates                          2.0
# 50   UnitedStates                          2.0
# 65            NaN                          2.0
# 86            NaN                          2.0
# 89            NaN                          2.0
# 94            NaN                          2.0
# 106           NaN                          2.0
# 109           NaN                          2.0
# 111           NaN                          2.0
# 116           NaN                          2.0
# 117  UnitedStates                          1.0
# 120  UnitedStates                          NaN
# 133  UnitedStates                          2.0
# 139           NaN                          2.0
#
#     Driver License Jurisdiction Text Format Drivers License Issued By  \
# 1                                     State                        CT
# 50                                    State                        CT
# 65                                    State                        CT
# 86                                    State                        NY
# 89                                    State                        CT
# 94                                    State                        CT
# 106                                   State                        CT
# 109                                   State                        CT
# 111                                   State                        CT
# 116                                   State               CT  ID ONLY
# 117                            Not Licensed                       NaN
# 120                                     NaN                        CT
# 133                                   State                        CT
# 139                                   State                        CT
#
#      Drivers License Class  Commercial License Class  \
# 1                      4.0                       1.0
# 50                     4.0                       1.0
# 65                     4.0                       1.0
# 86                     NaN                       NaN
# 89                     5.0                       1.0
# 94                     4.0                       1.0
# 106                    4.0                       1.0
# 109                    4.0                       1.0
# 111                    4.0                       1.0
# 116                    0.0                       1.0
# 117                    NaN                       NaN
# 120                    NaN                       NaN
# 133                    4.0                       2.0
# 139                    4.0                       1.0
#
#     Commercial License Class Text Format  \
# 1                                     No
# 50                                    No
# 65                                    No
# 86                                   NaN
# 89                                    No
# 94                                    No
# 106                                   No
# 109                                   No
# 111                                   No
# 116                                   No
# 117                                  NaN
# 120                                  NaN
# 133                                  Yes
# 139                                   No
#
#      Transported to First Medical Facility By  \
# 1                                           1
# 50                                          3
# 65                                          3
# 86                                          1
# 89                                          3
# 94                                          1
# 106                                         1
# 109                                         1
# 111                                         3
# 116                                         3
# 117                                         1
# 120                                         3
# 133                                         3
# 139                                         3
#
#     Transported to First Medical Facility By Text Format  \
# 1                                      Not Transported
# 50                                          EMS Ground
# 65                                          EMS Ground
# 86                                     Not Transported
# 89                                          EMS Ground
# 94                                     Not Transported
# 106                                    Not Transported
# 109                                    Not Transported
# 111                                         EMS Ground
# 116                                         EMS Ground
# 117                                    Not Transported
# 120                                         EMS Ground
# 133                                         EMS Ground
# 139                                         EMS Ground
#
#     Name of the EMS agency Name of the Intended Receiving Facility
# 1                      NaN                                     NaN
# 50                    SEMS                       STAMFORD HOSPITAL
# 65               Salem EMS                         BACKUS HOSPITAL
# 86                     ASM                                     NaN
# 89      American Ambulance                                  BACKUS
# 94                     NaN                                     NaN
# 106                 Hebron                                     NaN
# 109                    NaN                                     NaN
# 111                Lebanon                         BACKUS HOSPITAL
# 116      Trinity Ambulance                      Waterbury Hospital
# 117                    NaN                                     NaN
# 120                    AMR                 Yale New Haven Hospital
# 133           MILFORD FIRE                 YALE NEW HAVEN HOSPITAL
# 139                    ASM                       Hartford Hospital

# %% [markdown]
# Out of curiosity, I wanted to know the most affected age range (5-year age range)

# %%
# Create five-year age ranges and count the occurrences in the dataset
fatal_injury_k_data['Age Range'] = pd.cut(fatal_injury_k_data['Age'], bins=range(0, 105, 5))

# Count the number of occurrences in each age range
age_range_counts = fatal_injury_k_data['Age Range'].value_counts().sort_index()

# Find the most affected age range
most_affected_age_range = age_range_counts.idxmax()
most_affected_age_range_count = age_range_counts.max()

most_affected_age_range, most_affected_age_range_count
# Out:
# (Interval(20, 25, closed='right'), 20)
